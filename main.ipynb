# %%
import app.db.db_conn as db_conn
import psycopg2 as pg

# %%
from app.db.db_conn import db, cur

# %%
cur.execute("SELECT * FROM app_user;")
rows = cur.fetchall()
print(rows)
# Out:
# [(3, 'admin', None, None, 'admin', True, datetime.datetime(2025, 12, 4, 1, 17, 15, 295267), datetime.datetime(2025, 12, 4, 1, 17, 15, 295267)), (4, 'staff', None, None, 'staff', True, datetime.datetime(2025, 12, 4, 1, 17, 15, 295267), datetime.datetime(2025, 12, 4, 1, 17, 15, 295267)), (5, 'alice', None, None, 'alice', True, datetime.datetime(2025, 12, 4, 1, 17, 15, 295267), datetime.datetime(2025, 12, 4, 1, 17, 15, 295267))]

# %%
cur.execute("commit;")
