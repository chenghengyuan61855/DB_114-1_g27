# %%
import os
a = os.getenv("DB_PASSWORD")
a

# %%
import db_conn as db
conn = db.connect()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 import db_conn as db
# ----> 2 conn = db.connect()
#
# File c:\桌面\DB\Final Project\DB_114-1_g27\db_conn.py:16, in connect()
#      14 global db, cur
#      15 if DB_PASSWORD is None:
# ---> 16     raise RuntimeError("DB_PASSWORD is not set")
#      17 try:
#      18     db = psycopg2.connect(
#      19         dbname=DB_NAME,
#      20         user=DB_USER,
#    (...)
#      23         port=DB_PORT
#      24     )
#
# RuntimeError: DB_PASSWORD is not set
